# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np
import os

from sklearn.model_selection import train_test_split

from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier

from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, roc_auc_score

import ollama

from tqdm import tqdm
from collections import defaultdict

from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder

from scipy.spatial.distance import pdist
from sklearn.decomposition import PCA

# %% [markdown]
# # Parameters

# %%
# List of models
ml_models = [
    ('Logistic Regression', LogisticRegression(random_state=42)),
    ('Random Forest', RandomForestClassifier(random_state=42)),
    ('SVM', SVC(random_state=42)),
    ('KNN', KNeighborsClassifier()),
    ('Gradient Boosting', GradientBoostingClassifier(random_state=42))
]

# %%
# Number of rows to synthesize
n_rows = 5000

# %%
# Different temperatures for LLM at which data will be synthesized
temperatures = [5, 10, 15]

# %%
# CSV file names
base_data_prep_name = "tabular_data_preprocessed_2025_04_03.csv"

# %%
# Force CUDA usage
os.environ["OLLAMA_BACKEND"] = "cuda"
os.environ["OLLAMA_NUM_THREADS"] = "16"

# %% [markdown]
# # Load Data

# %%
df = pd.read_csv(base_data_prep_name)

# %%
df.head()
# Out:
#         age  workclass  education_num  occupation  capital_gain  capital_loss  \
# 0  0.025996   2.137359       1.136512   -1.318460      0.146932     -0.217127
# 1  0.828308   1.454401       1.136512   -0.609318     -0.144804     -0.217127
# 2 -0.046942   0.088484      -0.419335   -0.136557     -0.144804     -0.217127
# 3  1.047121   0.088484      -1.197259   -0.136557     -0.144804     -0.217127
# 4 -0.776316   0.088484       1.136512    0.808965     -0.144804     -0.217127
#
#    hours_per_week  native_country  income  relationship_not_in_family  ...  \
# 0       -0.034087        0.289462       0                    1.697524  ...
# 1       -2.213032        0.289462       0                   -0.589093  ...
# 2       -0.034087        0.289462       0                    1.697524  ...
# 3       -0.034087        0.289462       0                   -0.589093  ...
# 4       -0.034087       -4.083380       0                   -0.589093  ...
#
#    marital_status_married_civ_spouse  marital_status_married_spouse_absent  \
# 0                          -0.919604                             -0.114128
# 1                           1.087425                             -0.114128
# 2                          -0.919604                             -0.114128
# 3                           1.087425                             -0.114128
# 4                           1.087425                             -0.114128
#
#    marital_status_never_married  marital_status_separated  \
# 0                      1.424944                 -0.179829
# 1                     -0.701782                 -0.179829
# 2                     -0.701782                 -0.179829
# 3                     -0.701782                 -0.179829
# 4                     -0.701782                 -0.179829
#
#    marital_status_widowed  race_asian_pac_islander  race_black  race_other  \
# 0                 -0.1791                -0.179161   -0.325728   -0.091554
# 1                 -0.1791                -0.179161   -0.325728   -0.091554
# 2                 -0.1791                -0.179161   -0.325728   -0.091554
# 3                 -0.1791                -0.179161    3.070047   -0.091554
# 4                 -0.1791                -0.179161    3.070047   -0.091554
#
#    race_white  sex_male
# 0    0.411743   0.70422
# 1    0.411743   0.70422
# 2    0.411743   0.70422
# 3   -2.428701   0.70422
# 4   -2.428701  -1.42001
#
# [5 rows x 25 columns]

# %% [markdown]
# ### Proxy meassures for homogeneity of base data

# %%
def euclidean(df):
    distances = pdist(df, metric='euclidean')
    avg_distance = np.mean(distances)
    print("Average pairwise distance:", avg_distance)


def pca(df):
    pca = PCA(n_components=3)
    transformed = pca.fit_transform(df)
    explained_variance = pca.explained_variance_ratio_
    print("Explained variance ratio:", explained_variance)
    
    cumulative_variance = np.sum(pca.explained_variance_ratio_)
    print("Cumulative explained variance:", cumulative_variance)

# %%
euclidean(df)
pca(df)
# Out:
# Average pairwise distance: 6.391776639787022
# Explained variance ratio: [0.12171479 0.08500064 0.07121668]
# Cumulative explained variance: 0.2779321020922514

# %% [markdown]
# # Experimential setup

# %%
# Split the data into training test set
X_train, X_test, y_train, y_test = train_test_split(df.drop('income', axis=1), df['income'], test_size=0.2, random_state=42)

# Print the shapes of the sets
print(f"Training Set: X_train shape = {X_train.shape}, y_train shape = {y_train.shape}")
print(f"Test Set: X_test shape = {X_test.shape}, y_test shape = {y_test.shape}")
# Out:
# Training Set: X_train shape = (39073, 24), y_train shape = (39073,)
# Test Set: X_test shape = (9769, 24), y_test shape = (9769,)

# %% [markdown]
# # Modeling and Performance metrics

# %%
# Function to train and evaluate models with multiple metrics
def evaluate_models_with_metrics(models, X_train, y_train, X_test, y_test):
    results = []
    
    for name, model in models:
        # Train the model
        model.fit(X_train, y_train)
        
        # Predict on test set
        y_test_pred = model.predict(X_test)

        # Store results for the model
        model_results = {
            'Model': name,
            'Test Accuracy': accuracy_score(y_test, y_test_pred),
            'Test Precision': precision_score(y_test, y_test_pred),
            'Test Recall': recall_score(y_test, y_test_pred),
            'Test F1-Score': f1_score(y_test, y_test_pred)
        }
        
        results.append(model_results)

    # Convert results to a pandas DataFrame
    results_df = pd.DataFrame(results)
    
    return results_df

# %%
# Evaluate models with multiple metrics and print results
results_normal = evaluate_models_with_metrics(ml_models, X_train, y_train, X_test, y_test)
display(results_normal)
# Out:
#                  Model  Test Accuracy  Test Precision  Test Recall  \
# 0  Logistic Regression       0.841744        0.725097     0.553291
# 1        Random Forest       0.847989        0.719033     0.606369
# 2                  SVM       0.845634        0.760615     0.524841
# 3                  KNN       0.829358        0.672518     0.569427
# 4    Gradient Boosting       0.866414        0.792969     0.603397
#
#    Test F1-Score
# 0       0.627649
# 1       0.657913
# 2       0.621106
# 3       0.616693
# 4       0.685315

# %% [markdown]
# # Data synthesis experiment

# %% [markdown]
# In the case where you have little data you can use LLMs to generate data (with controlled feature variability)
#
# To prove that this works we can set up the following experiment
# 1. Train a model with 100 rows (small sample size)
# 2. Train another model with 200 rows where 100 rows from the existing set and then 100 rows generated from the LLM
# 3. Test first model on test set and validation set
# 4. Test second model on test set and validation set
# 5. Compare performance metrics

# %% [markdown]
# ### Let's quickly make the base DF with our low sample size (100 samples)

# %%
# Split the data into training and test sets
X_train_base, X_test_base, y_train_base, y_test_base = train_test_split(df.drop('income', axis=1), df['income'], test_size=0.2, random_state=42)
X_train_base = X_train_base[0:99]
y_train_base = y_train_base[0:99]

# Print the shapes of the sets
print(f"Training Set: X_train shape = {X_train_base.shape}, y_train shape = {y_train_base.shape}")
print(f"Test Set: X_test shape = {X_test_base.shape}, y_test shape = {y_test_base.shape}")

base_results = []
  
for name, ml_model in ml_models:
    # Train the model
    ml_model.fit(X_train_base, y_train_base)
    
    # Predict on test set
    y_test_pred_base = ml_model.predict(X_test_base)

    # Store results for the model
    model_results = {
        'Model': name,
        'Test Accuracy': accuracy_score(y_test_base, y_test_pred_base),
        'Test Precision': precision_score(y_test_base, y_test_pred_base),
        'Test Recall': recall_score(y_test_base, y_test_pred_base),
        'Test F1-Score': f1_score(y_test_base, y_test_pred_base)
    }
    
    base_results.append(model_results)

# Convert results to a pandas DataFrame
base_results = pd.DataFrame(base_results).set_index("Model")
display(base_results)
# Out:
# Training Set: X_train shape = (99, 24), y_train shape = (99,)
# Test Set: X_test shape = (9769, 24), y_test shape = (9769,)
#                      Test Accuracy  Test Precision  Test Recall  Test F1-Score
# Model
# Logistic Regression       0.810523        0.636957     0.497665       0.558760
# Random Forest             0.813594        0.655413     0.478132       0.552909
# SVM                       0.803050        0.645510     0.405945       0.498436
# KNN                       0.791995        0.592338     0.439915       0.504873
# Gradient Boosting         0.804893        0.603504     0.555839       0.578691

# %% [markdown]
# ### Models that we will test

# %%
prompt = '''Generate ONE realistic data row where ALL fields align with the variable constraints and logically justify the Target (does the person earn more or less than 50k dollars). 
Return ONLY the pipe-separated row with NO additional text or explanations.

Mandatory Format (pipe-separated, exact order):
Age|Sex|Country|Marital-Status|Occupation|Workclass|Education|Race|Relationship|Hours-Weekly|Capital-Gain|Capital-Loss|Target

Variable Constraints (NO deviations allowed):
Age: Integer (17-90)
Sex: Male or Female
Country: Exact values from: United-States, Cambodia, England, Puerto-Rico, Canada, Germany, Outlying-US(Guam-USVI-etc), India, Japan, Greece, China, Cuba, Iran, Honduras, Philippines, Italy, Poland, Jamaica, Vietnam, Mexico, Portugal, Ireland, France, Dominican-Republic, Laos, Ecuador, Haiti, Columbia, Hungary, Guatemala, Nicaragua, Scotland, Thailand, Yugoslavia, El-Salvador, Trinadad&Tobago, Peru, Hong, Holand-Netherlands
Marital-Status: Exact values from: Married-civ-spouse, Divorced, Never-married, Separated, Widowed, Married-spouse-absent, Married-AF-spouse
Occupation: Exact values from: Tech-support, Craft-repair, Other-service, Sales, Exec-managerial, Prof-specialty, Handlers-cleaners, Machine-op-inspct, Adm-clerical, Farming-fishing, Transport-moving, Priv-house-serv, Protective-serv, Armed-Forces
Workclass: Exact values from: Private, Self-emp-not-inc, Self-emp-inc, Federal-gov, Local-gov, State-gov, Without-pay, Never-worked
Education: Exact values from: Bachelors, Some-college, 11th, HS-grad, Prof-school, Assoc-acdm, Assoc-voc, 9th, 7th-8th, 12th, Masters, 1st-4th, 10th, Doctorate, 5th-6th, Preschool
Race: Exact values from: White, Asian-Pac-Islander, Amer-Indian-Eskimo, Other, Black
Relationship: Exact values from: Wife, Own-child, Husband, Not-in-family, Other-relative, Unmarried
Hours-Weekly: Integer (1-99)
Capital-Gain: Non-negative integer (0-99999)
Capital-Loss: Non-negative integer (0-99999)
Target: >50K or <50K
'''

# %%
def validate_input(input_string):
    # Split the input string by pipe character
    fields = input_string.split('|')
    assert len(fields) == 13, "Input must have exactly 13 fields separated by |"
    
    # Unpack all fields
    age, sex, country, marital_status, occupation, workclass, education, race, relationship, hours_weekly, capital_gain, capital_loss, target = fields
    
    # Validate Age
    age = int(age)
    assert 17 <= age <= 90, "Age must be between 17 and 90"
    
    # Validate Sex
    assert sex in {'Male', 'Female'}, "Sex must be either Male or Female"
    
    # Validate Country
    valid_countries = {
        'United-States', 'Cambodia', 'England', 'Puerto-Rico', 'Canada', 'Germany',
        'Outlying-US(Guam-USVI-etc)', 'India', 'Japan', 'Greece', 'China', 'Cuba',
        'Iran', 'Honduras', 'Philippines', 'Italy', 'Poland', 'Jamaica', 'Vietnam',
        'Mexico', 'Portugal', 'Ireland', 'France', 'Dominican-Republic', 'Laos',
        'Ecuador', 'Haiti', 'Columbia', 'Hungary', 'Guatemala', 'Nicaragua',
        'Scotland', 'Thailand', 'Yugoslavia', 'El-Salvador', 'Trinadad&Tobago',
        'Peru', 'Hong', 'Holand-Netherlands'
    }
    assert country in valid_countries, f"Invalid country: {country}"
    
    # Validate Marital-Status
    valid_marital_statuses = {
        'Married-civ-spouse', 'Divorced', 'Never-married', 'Separated', 'Widowed',
        'Married-spouse-absent', 'Married-AF-spouse'
    }
    assert marital_status in valid_marital_statuses, f"Invalid marital status: {marital_status}"
    
    # Validate Occupation
    valid_occupations = {
        'Tech-support', 'Craft-repair', 'Other-service', 'Sales', 'Exec-managerial',
        'Prof-specialty', 'Handlers-cleaners', 'Machine-op-inspct', 'Adm-clerical',
        'Farming-fishing', 'Transport-moving', 'Priv-house-serv', 'Protective-serv',
        'Armed-Forces'
    }
    assert occupation in valid_occupations, f"Invalid occupation: {occupation}"
    
    # Validate Workclass
    valid_workclasses = {
        'Private', 'Self-emp-not-inc', 'Self-emp-inc', 'Federal-gov', 'Local-gov',
        'State-gov', 'Without-pay', 'Never-worked'
    }
    assert workclass in valid_workclasses, f"Invalid workclass: {workclass}"
    
    # Validate Education
    valid_educations = {
        'Bachelors', 'Some-college', '11th', 'HS-grad', 'Prof-school', 'Assoc-acdm',
        'Assoc-voc', '9th', '7th-8th', '12th', 'Masters', '1st-4th', '10th',
        'Doctorate', '5th-6th', 'Preschool'
    }
    assert education in valid_educations, f"Invalid education: {education}"
    
    # Validate Race
    valid_races = {
        'White', 'Asian-Pac-Islander', 'Amer-Indian-Eskimo', 'Other', 'Black'
    }
    assert race in valid_races, f"Invalid race: {race}"
    
    # Validate Relationship
    valid_relationships = {
        'Wife', 'Own-child', 'Husband', 'Not-in-family', 'Other-relative', 'Unmarried'
    }
    assert relationship in valid_relationships, f"Invalid relationship: {relationship}"
    
    # Validate Hours-Weekly
    hours_weekly = int(hours_weekly)
    assert 1 <= hours_weekly <= 99, "Hours per week must be between 1 and 99"
    
    # Validate Capital-Gain
    capital_gain = int(capital_gain)
    assert 0 <= capital_gain <= 99999, "Capital gain must be between 0 and 99999"
    
    # Validate Capital-Loss
    capital_loss = int(capital_loss)
    assert 0 <= capital_loss <= 99999, "Capital loss must be between 0 and 99999"
    
    # Validate Target
    assert target in {'>50K', '<50K'}, "Target must be either >50K or <50K"
    
    return True

# %% [markdown]
# ### Demonstration that "dumb" models have too much error

# %%
models = ['llama3.2:1b', 'llama3.2:3b']

# %%
# Initialize a dictionary to store results and errors per model
results = {}
error_counts_per_model = defaultdict(lambda: defaultdict(int))

# Iterate through models
for index, model in enumerate(models):
    print("Processing Model: " + model + " (Model " + str(index + 1) + "/" + str(len(models)) + ")")
    results[model] = []
    retries = 0
    valid_samples = 0
    total_samples = 0

    # Loop through the n_rows instances for each model
    for _ in tqdm(range(n_rows), desc=f"Generating Samples for {model}", leave=True):
        total_samples += 1
        try:
            # Generate data
            response = ollama.generate(model=model, prompt=prompt)['response']

            # Check if the response is valid
            validate_input(response)

            # Store the valid response
            results[model].append(response)
            valid_samples += 1
        except Exception as e:
            # Store error per model
            error_counts_per_model[model][str(e)] += 1
            retries += 1

            # Stop early for this model if too many errors (>10% errors)
            if retries >= int(n_rows*0.1):
                print(f"Too many errors for model {model}, stopping early.")
                break  

    # Calculate error rate
    error_rate = (retries / total_samples) * 100
    print(f"Model {model} Error Rate: {error_rate:.2f}%")

    # Print error summary for the current model
    print(f"Error Distribution Summary for Model {model}:")
    for error_msg, count in error_counts_per_model[model].items():
        print(f"  {error_msg}: {count} occurrences")
    print()
# Out:
# Processing Model: llama3.2:1b (Model 1/2)
# Generating Samples for llama3.2:1b:  10%|████████████████████▌                                                                                                                                                                                        | 501/5000 [06:04<54:33,  1.37it/s]
# Too many errors for model llama3.2:1b, stopping early.
# Model llama3.2:1b Error Rate: 99.60%
# Error Distribution Summary for Model llama3.2:1b:
#   Input must have exactly 13 fields separated by |: 356 occurrences
#   Invalid workclass: Other-service: 3 occurrences
#   Invalid workclass: Exec-managerial: 7 occurrences
#   Age must be between 17 and 90: 56 occurrences
#   invalid literal for int() with base 10: '$100000': 1 occurrences
#   Sex must be either Male or Female: 16 occurrences
#   invalid literal for int() with base 10: '0.00000+': 1 occurrences
#   Capital loss must be between 0 and 99999: 17 occurrences
#   Target must be either >50K or <50K: 5 occurrences
#   Invalid workclass: Prof-specialty: 6 occurrences
#   Invalid marital status: Marry-civ-spouse: 8 occurrences
#   Invalid race: None: 1 occurrences
#   Invalid education: Education:Bachelors: 6 occurrences
#   Capital gain must be between 0 and 99999: 6 occurrences
#   Invalid education: Education:Prof-specialty: 1 occurrences
#   Invalid marital status: MARRIEd-civ-spouse: 1 occurrences
#   Invalid education: Bachelor: 1 occurrences
#   Invalid education: Bachelor's: 1 occurrences
#   invalid literal for int() with base 10: '100000+': 1 occurrences
#   Invalid marital status: Marry-ed-civ-spouse: 1 occurrences
#   Invalid marital status: Maiden: 1 occurrences
#   Invalid marital status: March-Divorced: 1 occurrences
#   Invalid education: Education: Bachelors: 1 occurrences
#   invalid literal for int() with base 10: 'Bachelors': 1 occurrences
#   Invalid marital status: Marrid-civ-spouse: 1 occurrences
#
# Processing Model: llama3.2:3b (Model 2/2)
# Generating Samples for llama3.2:3b:  13%|██████████████████████████▍                                                                                                                                                                                | 650/5000 [13:20<1:29:18,  1.23s/it]
# Too many errors for model llama3.2:3b, stopping early.
# Model llama3.2:3b Error Rate: 76.80%
# Error Distribution Summary for Model llama3.2:3b:
#   Input must have exactly 13 fields separated by |: 187 occurrences
#   Sex must be either Male or Female: 280 occurrences
#   Invalid marital status: Maiden-head-of-house-hold: 1 occurrences
#   Invalid marital status: Maiden-civ-spouse: 2 occurrences
#   Age must be between 17 and 90: 7 occurrences
#   Capital loss must be between 0 and 99999: 13 occurrences
#   Invalid marital status: Maiden-Married-civ-spouse: 1 occurrences
#   Capital gain must be between 0 and 99999: 1 occurrences
#   Invalid occupation: Farmers-fishers-and-related-occupations: 1 occurrences
#   Invalid marital status: Merged-civ-spouse: 1 occurrences
#   Target must be either >50K or <50K: 3 occurrences
#   Invalid relationship: Married-spouse-absent: 1 occurrences
#   Invalid education: Private: 1 occurrences
#   Invalid marital status: Maiden-head-of-household: 1 occurrences

# %% [markdown]
# ### Hence we use smart enough models

# %%
models = ['llama3.1', 'mistral']

# %% [markdown]
# ### Lets generate some data
# We will use different temperature and use it as a paramter to see if we can get less homogeneous data

# %%
# Initialize a dictionary to store results and errors per model
results = {}
error_counts_per_model = defaultdict(lambda: defaultdict(lambda: defaultdict(int)))

# Iterate through models
for index, model in enumerate(models):
    print("Processing Model: " + model + " (Model " + str(index + 1) + "/" + str(len(models)) + ")")
    results[model] = {}

    # Loop through the different temperatures
    for temperature in temperatures:
        print(f"  Using Temperature: {temperature}")
        results[model][temperature] = []
        retries = 0
        valid_samples = 0
        total_samples = 0
        
        # Loop through the x instances for each temperature setting
        for _ in tqdm(range(n_rows), desc=f"Generating Samples for {model} with Temp {temperature}", leave=True):
            total_samples += 1
            try:
                # Generate data with the specified temperature
                response = ollama.generate(model=model, prompt=prompt, options={"temperature": temperature})['response']

                # Check if the response is valid
                validate_input(response)

                # Store the valid response
                results[model][temperature].append(response)
                valid_samples += 1
            except Exception as e:
                # Store error per model and temperature
                error_counts_per_model[model][temperature][str(e)] += 1
                retries += 1

        # Calculate error rate
        error_rate = (retries / total_samples) * 100
        print(f"  Model {model} at Temp {temperature} - Error Rate: {error_rate:.2f}%")

        # Print error summary for the current model and temperature
        print(f"  Error Distribution Summary for Model {model} at Temp {temperature}:")
        for error_msg, count in error_counts_per_model[model][temperature].items():
            print(f"    {error_msg}: {count} occurrences")    
        print()
# Out:
# Processing Model: llama3.1 (Model 1/2)
#   Using Temperature: 5
# Generating Samples for llama3.1 with Temp 5: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 5000/5000 [6:21:19<00:00,  4.58s/it]
#   Model llama3.1 at Temp 5 - Error Rate: 26.50%
#   Error Distribution Summary for Model llama3.1 at Temp 5:
#     Input must have exactly 13 fields separated by |: 251 occurrences
#     Capital loss must be between 0 and 99999: 260 occurrences
#     invalid literal for int() with base 10: '1231>': 1 occurrences
#     Sex must be either Male or Female: 251 occurrences
#     Invalid country: MEXICO: 83 occurrences
#     invalid literal for int() with base 10: '': 33 occurrences
#     invalid literal for int() with base 10: 'Age': 174 occurrences
#     Invalid country: MEX: 60 occurrences
#     invalid literal for int() with base 10: '1022>': 1 occurrences
#     invalid literal for int() with base 10: '1507>': 2 occurrences
#     invalid literal for int() with base 10: '1001>': 2 occurrences
#     invalid literal for int() with base 10: '1021>': 1 occurrences
#     Capital gain must be between 0 and 99999: 17 occurrences
#     invalid literal for int() with base 10: '2304>': 1 occurrences
#     invalid literal for int() with base 10: '1546>': 1 occurrences
#     invalid literal for int() with base 10: '2357>': 2 occurrences
#     invalid literal for int() with base 10: '3008>': 1 occurrences
#     invalid literal for int() with base 10: '1703>': 1 occurrences
#     Target must be either >50K or <50K: 25 occurrences
#     invalid literal for int() with base 10: '1308>': 1 occurrences
#     Invalid country: MEXICOF: 1 occurrences
#     invalid literal for int() with base 10: '1208>': 1 occurrences
#     invalid literal for int() with base 10: '5432>': 1 occurrences
#     invalid literal for int() with base 10: '24000>': 3 occurrences
#     invalid literal for int() with base 10: '1705>': 2 occurrences
#     invalid literal for int() with base 10: '21312>': 1 occurrences
#     Invalid country: MEXICOR: 1 occurrences
#     invalid literal for int() with base 10: '2847>': 1 occurrences
#     invalid literal for int() with base 10: '30-35': 2 occurrences
#     Invalid country: MEXICOFemale: 1 occurrences
#     invalid literal for int() with base 10: '12030>': 1 occurrences
#     invalid literal for int() with base 10: '3456>': 2 occurrences
#     invalid literal for int() with base 10: '2000>': 2 occurrences
#     Invalid country: MEXICo: 9 occurrences
#     invalid literal for int() with base 10: '1207>': 1 occurrences
#     invalid literal for int() with base 10: '-1117>': 1 occurrences
#     invalid literal for int() with base 10: '2305>': 1 occurrences
#     Invalid country: MEXICCO: 7 occurrences
#     invalid literal for int() with base 10: '4207>': 2 occurrences
#     invalid literal for int() with base 10: '2406>': 2 occurrences
#     invalid literal for int() with base 10: '2104>': 2 occurrences
#     invalid literal for int() with base 10: '4000>': 1 occurrences
#     invalid literal for int() with base 10: '30-45': 1 occurrences
#     invalid literal for int() with base 10: '4567>': 1 occurrences
#     invalid literal for int() with base 10: '2101>': 2 occurrences
#     invalid literal for int() with base 10: '12345>': 4 occurrences
#     invalid literal for int() with base 10: '1099>': 1 occurrences
#     Invalid country: MEXICAN: 2 occurrences
#     invalid literal for int() with base 10: '-1215>': 1 occurrences
#     invalid literal for int() with base 10: '1508>': 1 occurrences
#     invalid literal for int() with base 10: '1501>': 1 occurrences
#     Invalid country: Males-Only: 1 occurrences
#     invalid literal for int() with base 10: '1502>': 1 occurrences
#     invalid literal for int() with base 10: '2303>': 2 occurrences
#     invalid literal for int() with base 10: '2131>': 1 occurrences
#     invalid literal for int() with base 10: '1457>': 1 occurrences
#     invalid literal for int() with base 10: '3490>': 1 occurrences
#     invalid literal for int() with base 10: '2122>': 1 occurrences
#     invalid literal for int() with base 10: '1274>': 1 occurrences
#     invalid literal for int() with base 10: '2103>': 1 occurrences
#     invalid literal for int() with base 10: '2349>': 2 occurrences
#     invalid literal for int() with base 10: '1503>': 1 occurrences
#     Invalid country: Males-Cuba-Female-Mexico: 1 occurrences
#     invalid literal for int() with base 10: '3207>': 1 occurrences
#     invalid literal for int() with base 10: '2308>': 2 occurrences
#     invalid literal for int() with base 10: '-2099>': 1 occurrences
#     invalid literal for int() with base 10: '15000>': 2 occurrences
#     invalid literal for int() with base 10: '2503>': 2 occurrences
#     invalid literal for int() with base 10: '2309>': 1 occurrences
#     invalid literal for int() with base 10: '2307>': 1 occurrences
#     invalid literal for int() with base 10: '10201>': 1 occurrences
#     invalid literal for int() with base 10: '2109>': 1 occurrences
#     invalid literal for int() with base 10: '5209>': 1 occurrences
#     invalid literal for int() with base 10: '30-34': 1 occurrences
#     Invalid country: MEXICOFemaleM: 1 occurrences
#     invalid literal for int() with base 10: '-3305>': 1 occurrences
#     Invalid country: MEXICOCity: 1 occurrences
#     invalid literal for int() with base 10: '1709>': 1 occurrences
#     invalid literal for int() with base 10: '1212>': 1 occurrences
#     invalid literal for int() with base 10: '2251>': 1 occurrences
#     invalid literal for int() with base 10: '-1>': 2 occurrences
#     invalid literal for int() with base 10: '2205>': 1 occurrences
#     Invalid relationship: Other: 3 occurrences
#     invalid literal for int() with base 10: '30-49': 1 occurrences
#     invalid literal for int() with base 10: '2203>': 1 occurrences
#     invalid literal for int() with base 10: '4561>': 1 occurrences
#     invalid literal for int() with base 10: '2102>': 1 occurrences
#     invalid literal for int() with base 10: '2647>': 1 occurrences
#     invalid literal for int() with base 10: '23456>': 1 occurrences
#     invalid literal for int() with base 10: '50000>': 1 occurrences
#     invalid literal for int() with base 10: '2402>': 1 occurrences
#     invalid literal for int() with base 10: '1222>': 1 occurrences
#     Invalid country: MEXICOCity: Muncie : 1 occurrences
#     Invalid country: Males: 1 occurrences
#     invalid literal for int() with base 10: '90000>': 1 occurrences
#     invalid literal for int() with base 10: '4286>': 1 occurrences
#     invalid literal for int() with base 10: '2604>': 1 occurrences
#     invalid literal for int() with base 10: '18000>': 2 occurrences
#     invalid literal for int() with base 10: '1234>': 1 occurrences
#     invalid literal for int() with base 10: '2342>': 1 occurrences
#     invalid literal for int() with base 10: '3434>': 1 occurrences
#     invalid literal for int() with base 10: '-1806>': 1 occurrences
#     invalid literal for int() with base 10: '-1997>': 1 occurrences
#     invalid literal for int() with base 10: '1039>': 1 occurrences
#     invalid literal for int() with base 10: '3209>': 2 occurrences
#     invalid literal for int() with base 10: '5008>': 1 occurrences
#     invalid literal for int() with base 10: '3005>': 1 occurrences
#     invalid literal for int() with base 10: '10992>': 1 occurrences
#     invalid literal for int() with base 10: '2302>': 1 occurrences
#     invalid literal for int() with base 10: '3433>': 1 occurrences
#     Invalid country: MEXICAN-Married-spouse-absent : 1 occurrences
#     invalid literal for int() with base 10: '2475>': 1 occurrences
#     invalid literal for int() with base 10: '-1805>': 1 occurrences
#     invalid literal for int() with base 10: '1-6': 1 occurrences
#     invalid literal for int() with base 10: '4203>': 1 occurrences
#     invalid literal for int() with base 10: '1403>': 1 occurrences
#     invalid literal for int() with base 10: '1081>': 1 occurrences
#     invalid literal for int() with base 10: '3500>': 1 occurrences
#     invalid literal for int() with base 10: '8005>': 1 occurrences
#     invalid literal for int() with base 10: '37.2': 1 occurrences
#     Invalid occupation: Service-industry: 1 occurrences
#     invalid literal for int() with base 10: '12112>': 1 occurrences
#     invalid literal for int() with base 10: '13567>': 1 occurrences
#     invalid literal for int() with base 10: '3201>': 1 occurrences
#     invalid literal for int() with base 10: '30-40': 1 occurrences
#     invalid literal for int() with base 10: '-3901>': 1 occurrences
#     invalid literal for int() with base 10: '4808>': 1 occurrences
#     Invalid country: MEXICAN-CAM: 1 occurrences
#     invalid literal for int() with base 10: '1202>': 1 occurrences
#     Invalid country: MEXICOCountry: United-States: 1 occurrences
#     invalid literal for int() with base 10: '2507>': 1 occurrences
#     invalid literal for int() with base 10: '2132>': 1 occurrences
#     invalid literal for int() with base 10: '2202>': 1 occurrences
#     Invalid country: MEXICAN-CO: 1 occurrences
#     invalid literal for int() with base 10: '2341>': 1 occurrences
#     invalid literal for int() with base 10: '1431>': 1 occurrences
#     invalid literal for int() with base 10: '1505>': 1 occurrences
#     invalid literal for int() with base 10: '3452>': 1 occurrences
#     Invalid country: MEXICOLocal-gov: 1 occurrences
#
#   Using Temperature: 10
# Generating Samples for llama3.1 with Temp 10: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 5000/5000 [7:53:11<00:00,  5.68s/it]
#   Model llama3.1 at Temp 10 - Error Rate: 27.28%
#   Error Distribution Summary for Model llama3.1 at Temp 10:
#     Capital loss must be between 0 and 99999: 295 occurrences
#     invalid literal for int() with base 10: 'Age': 121 occurrences
#     Sex must be either Male or Female: 215 occurrences
#     Input must have exactly 13 fields separated by |: 253 occurrences
#     Invalid country: MEX: 68 occurrences
#     Capital gain must be between 0 and 99999: 22 occurrences
#     invalid literal for int() with base 10: '': 44 occurrences
#     Invalid country: MEXICAN-HISPANIC-SPANISH ORIG, SPC 1ORIGIN-MOREAN-CUBAN-BAYESIAN-DONUT SPARROWHEADS-SI AM-PRT-LTH-OTHER-CARA CAB ROLLERS-TURCO: 1 occurrences
#     invalid literal for int() with base 10: '3204>': 2 occurrences
#     Invalid country: MEXICOFemale : 1 occurrences
#     Invalid country: MEXICO: 95 occurrences
#     Invalid country: MEXICAN-HISPANIC: 1 occurrences
#     invalid literal for int() with base 10: '3201>': 2 occurrences
#     invalid literal for int() with base 10: '-1995>': 1 occurrences
#     invalid literal for int() with base 10: '2343>': 1 occurrences
#     Invalid country: MEXICOR: 1 occurrences
#     Invalid country: MEXICCO: 5 occurrences
#     Invalid country: MEXICo: 10 occurrences
#     invalid literal for int() with base 10: '2908>': 1 occurrences
#     Target must be either >50K or <50K: 18 occurrences
#     invalid literal for int() with base 10: '2607>': 1 occurrences
#     invalid literal for int() with base 10: '5205>': 1 occurrences
#     invalid literal for int() with base 10: '3202>': 2 occurrences
#     invalid literal for int() with base 10: '4568>': 1 occurrences
#     invalid literal for int() with base 10: '30-35': 2 occurrences
#     invalid literal for int() with base 10: '-2305>': 1 occurrences
#     invalid literal for int() with base 10: '12345>': 3 occurrences
#     invalid literal for int() with base 10: '2274>': 1 occurrences
#     invalid literal for int() with base 10: '1507>': 1 occurrences
#     invalid literal for int() with base 10: '-1>': 4 occurrences
#     Invalid country: MEXICOFemale-Married-spouse-absent: 1 occurrences
#     invalid literal for int() with base 10: '1805>': 1 occurrences
#     invalid literal for int() with base 10: '2104>': 1 occurrences
#     invalid literal for int() with base 10: '1-8000': 1 occurrences
#     invalid literal for int() with base 10: '2501>': 4 occurrences
#     invalid literal for int() with base 10: '2357>': 1 occurrences
#     invalid literal for int() with base 10: '1096>': 1 occurrences
#     invalid literal for int() with base 10: '2131>': 1 occurrences
#     invalid literal for int() with base 10: '48000>': 1 occurrences
#     invalid literal for int() with base 10: '1212>': 3 occurrences
#     Invalid occupation: Service : 1 occurrences
#     Invalid country: MEXICOCountry: 2 occurrences
#     invalid literal for int() with base 10: '1234>': 3 occurrences
#     invalid literal for int() with base 10: '30-45': 3 occurrences
#     invalid literal for int() with base 10: '3001>': 3 occurrences
#     Invalid country: MEXICOLocal-gov: 6 occurrences
#     invalid literal for int() with base 10: '4562>': 1 occurrences
#     Invalid country: Males' spouses (Outlying-US(Guam-USVI-etc)): 1 occurrences
#     Invalid country: Males were mostly represented by census and some women like a Susan and Rose; thus, to meet the variable requirements we assign this record a 'Female' label in the row,  : 1 occurrences
#     invalid literal for int() with base 10: '2348>': 1 occurrences
#     invalid literal for int() with base 10: '8000>': 2 occurrences
#     Invalid country: MEXICAN-FEMALES: 1 occurrences
#     invalid literal for int() with base 10: '2345>': 5 occurrences
#     invalid literal for int() with base 10: '2407>': 1 occurrences
#     invalid literal for int() with base 10: '4203>': 2 occurrences
#     invalid literal for int() with base 10: '4206>': 1 occurrences
#     invalid literal for int() with base 10: '1.4': 1 occurrences
#     Invalid country: Maleski: 1 occurrences
#     invalid literal for int() with base 10: '2503>': 2 occurrences
#     invalid literal for int() with base 10: '2303>': 4 occurrences
#     Invalid relationship: Other: 1 occurrences
#     invalid literal for int() with base 10: '23456>': 1 occurrences
#     invalid literal for int() with base 10: '2133>': 1 occurrences
#     invalid literal for int() with base 10: '3407>': 1 occurrences
#     invalid literal for int() with base 10: '-4201>': 1 occurrences
#     invalid literal for int() with base 10: '3451>': 2 occurrences
#     invalid literal for int() with base 10: '8209>': 1 occurrences
#     invalid literal for int() with base 10: '3208>': 2 occurrences
#     invalid literal for int() with base 10: '-2004>': 1 occurrences
#     invalid literal for int() with base 10: '-3908>': 1 occurrences
#     invalid literal for int() with base 10: '2137>': 1 occurrences
#     invalid literal for int() with base 10: '4321>': 2 occurrences
#     invalid literal for int() with base 10: '2107>': 1 occurrences
#     Invalid country: MEXICAN-FEMALE-OWNER-MERCHANT-SHIP: 1 occurrences
#     invalid literal for int() with base 10: '6000>': 1 occurrences
#     invalid literal for int() with base 10: '5678>': 1 occurrences
#     invalid literal for int() with base 10: '3203>': 2 occurrences
#     invalid literal for int() with base 10: '-1705>': 1 occurrences
#     invalid literal for int() with base 10: '8001>': 1 occurrences
#     invalid literal for int() with base 10: '2259>': 1 occurrences
#     invalid literal for int() with base 10: '4204>': 1 occurrences
#     invalid literal for int() with base 10: '1701>': 1 occurrences
#     invalid literal for int() with base 10: '2108>': 1 occurrences
#     invalid literal for int() with base 10: '2207>': 2 occurrences
#     invalid literal for int() with base 10: '1023>': 1 occurrences
#     invalid literal for int() with base 10: '2106>': 1 occurrences
#     invalid literal for int() with base 10: '30-39': 2 occurrences
#     invalid literal for int() with base 10: '-3405>': 1 occurrences
#     invalid literal for int() with base 10: '8003>': 1 occurrences
#     invalid literal for int() with base 10: '1221>': 1 occurrences
#     invalid literal for int() with base 10: '6004>': 1 occurrences
#     invalid literal for int() with base 10: '-2105>': 1 occurrences
#     invalid literal for int() with base 10: '2342>': 2 occurrences
#     invalid literal for int() with base 10: '2504>': 1 occurrences
#     Invalid country: Males from these records are filtered out due to their non-target group (Female is chosen instead): 1 occurrences
#     invalid literal for int() with base 10: '2301>': 2 occurrences
#     invalid literal for int() with base 10: '1095>': 1 occurrences
#     invalid literal for int() with base 10: '4567>': 1 occurrences
#     invalid literal for int() with base 10: '2349>': 1 occurrences
#     invalid literal for int() with base 10: '2098>': 1 occurrences
#     invalid literal for int() with base 10: '30000>': 2 occurrences
#     invalid literal for int() with base 10: '4008>': 2 occurrences
#     invalid literal for int() with base 10: '37.7': 1 occurrences
#     invalid literal for int() with base 10: '24000>': 1 occurrences
#     invalid literal for int() with base 10: '2008>': 1 occurrences
#     Invalid race: Other,<40> White Female: 1 occurrences
#     invalid literal for int() with base 10: '2005>': 1 occurrences
#     invalid literal for int() with base 10: '30-31': 2 occurrences
#     invalid literal for int() with base 10: '30-40': 1 occurrences
#     invalid literal for int() with base 10: '4505>': 2 occurrences
#     invalid literal for int() with base 10: '2307>': 2 occurrences
#     Invalid country: MEXICOCITY: 1 occurrences
#     Invalid country: Males: 1 occurrences
#     Invalid country: MEXICAN-Mexico: 1 occurrences
#     invalid literal for int() with base 10: '1092>': 1 occurrences
#     invalid literal for int() with base 10: '2109>': 2 occurrences
#     invalid literal for int() with base 10: '1105>': 2 occurrences
#     invalid literal for int() with base 10: '2208>': 1 occurrences
#     invalid literal for int() with base 10: '1271>': 1 occurrences
#     invalid literal for int() with base 10: '1099>': 1 occurrences
#     Invalid occupation: Service-Sales: 1 occurrences
#     invalid literal for int() with base 10: '1086>': 1 occurrences
#     invalid literal for int() with base 10: '2105>': 1 occurrences
#     invalid literal for int() with base 10: '1357>': 1 occurrences
#     invalid literal for int() with base 10: '11111>': 1 occurrences
#     invalid literal for int() with base 10: '2306>': 1 occurrences
#     invalid literal for int() with base 10: '23000>': 2 occurrences
#     invalid literal for int() with base 10: '60000>': 1 occurrences
#     invalid literal for int() with base 10: '-1225>': 1 occurrences
#     invalid literal for int() with base 10: '5001>': 1 occurrences
#     Invalid country: MEXICAN: 1 occurrences
#     invalid literal for int() with base 10: '2309>': 1 occurrences
#     invalid literal for int() with base 10: '1582>': 1 occurrences
#     Invalid country: MEXICOCountry : 1 occurrences
#     invalid literal for int() with base 10: '1209>': 1 occurrences
#     Invalid country: Males-Family-Bachelors-US: 1 occurrences
#     invalid literal for int() with base 10: '2402>': 1 occurrences
#     invalid literal for int() with base 10: '1008>': 1 occurrences
#     invalid literal for int() with base 10: '2808>': 1 occurrences
#     invalid literal for int() with base 10: '2502>': 1 occurrences
#     invalid literal for int() with base 10: '1802>': 1 occurrences
#     invalid literal for int() with base 10: '2136>': 1 occurrences
#     Invalid country: MEXICOCountry of origin and ethnicity codes: 1 occurrences
#     invalid literal for int() with base 10: '2243>': 1 occurrences
#     invalid literal for int() with base 10: '3402>': 1 occurrences
#     invalid literal for int() with base 10: '3002>': 1 occurrences
#     invalid literal for int() with base 10: '2715>': 1 occurrences
#     invalid literal for int() with base 10: '-9001>': 1 occurrences
#     invalid literal for int() with base 10: '1222>': 1 occurrences
#     invalid literal for int() with base 10: '1457>': 1 occurrences
#     invalid literal for int() with base 10: '21095>': 1 occurrences
#     invalid literal for int() with base 10: '5008>': 1 occurrences
#     invalid literal for int() with base 10: '1022>': 1 occurrences
#     Invalid country: MEXICOCity: 1 occurrences
#     Invalid country: MEXICAN-US: 1 occurrences
#     Invalid country: MEXICORail-road: 1 occurrences
#     Invalid country: MEXICOCity,Mexico,Mexico is NOT listed, error in specification and  thus "Mexico" will be assumed.: 1 occurrences
#     invalid literal for int() with base 10: '4202>': 1 occurrences
#     invalid literal for int() with base 10: '220>': 1 occurrences
#     invalid literal for int() with base 10: '1287>': 1 occurrences
#     invalid literal for int() with base 10: '-2501>': 1 occurrences
#     invalid literal for int() with base 10: '3404>': 1 occurrences
#     invalid literal for int() with base 10: '1809>': 1 occurrences
#     invalid literal for int() with base 10: '2355>': 1 occurrences
#     invalid literal for int() with base 10: '15000>': 1 occurrences
#     invalid literal for int() with base 10: '4501>': 1 occurrences
#     invalid literal for int() with base 10: '2203>': 1 occurrences
#     Invalid country: MEXICORichmond VA USA,USA : 1 occurrences
#     invalid literal for int() with base 10: '2304>': 1 occurrences
#     invalid literal for int() with base 10: '8002>': 1 occurrences
#     invalid literal for int() with base 10: '4201>': 1 occurrences
#     invalid literal for int() with base 10: '3409>': 1 occurrences
#     Invalid country: MEXICORedundant Removed - Using only 'Mexico' for space. : 1 occurrences
#     invalid literal for int() with base 10: '4565>': 1 occurrences
#     Invalid country: Males' occupation as 'Other-service', Country as Vietnam : 1 occurrences
#     invalid literal for int() with base 10: '12245>': 1 occurrences
#     invalid literal for int() with base 10: '1005>': 1 occurrences
#
#   Using Temperature: 15
# Generating Samples for llama3.1 with Temp 15: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 5000/5000 [7:18:44<00:00,  5.26s/it]
#   Model llama3.1 at Temp 15 - Error Rate: 29.24%
#   Error Distribution Summary for Model llama3.1 at Temp 15:
#     invalid literal for int() with base 10: 'Age': 120 occurrences
#     Invalid country: MEXICAN: 4 occurrences
#     Input must have exactly 13 fields separated by |: 300 occurrences
#     Capital loss must be between 0 and 99999: 298 occurrences
#     Sex must be either Male or Female: 239 occurrences
#     Invalid country: MEXICOFederal-gov: 1 occurrences
#     invalid literal for int() with base 10: '1022>': 1 occurrences
#     Invalid country: MEX: 107 occurrences
#     invalid literal for int() with base 10: '1234>': 3 occurrences
#     Invalid country: MEXICO: 94 occurrences
#     Capital gain must be between 0 and 99999: 23 occurrences
#     invalid literal for int() with base 10: '2407>': 1 occurrences
#     invalid literal for int() with base 10: '': 47 occurrences
#     invalid literal for int() with base 10: '2304>': 1 occurrences
#     invalid literal for int() with base 10: '4201>': 2 occurrences
#     invalid literal for int() with base 10: '50000>': 5 occurrences
#     invalid literal for int() with base 10: '2341>': 4 occurrences
#     invalid literal for int() with base 10: '-3405>': 1 occurrences
#     invalid literal for int() with base 10: '2405>': 2 occurrences
#     Invalid occupation: Service-Admin.: 1 occurrences
#     Target must be either >50K or <50K: 17 occurrences
#     invalid literal for int() with base 10: '22082>': 1 occurrences
#     invalid literal for int() with base 10: '-2143>': 1 occurrences
#     invalid literal for int() with base 10: '13570>': 1 occurrences
#     Invalid country: MEXICOCity: 1 occurrences
#     invalid literal for int() with base 10: '23489>': 1 occurrences
#     Invalid country: MEXICOLocal-gov: 2 occurrences
#     invalid literal for int() with base 10: '30-45': 2 occurrences
#     Invalid country: MEXICAN-US: 1 occurrences
#     Invalid country: MEXICCO: 8 occurrences
#     invalid literal for int() with base 10: '1026>': 1 occurrences
#     invalid literal for int() with base 10: '3451>': 2 occurrences
#     Invalid country: MEXICORichards-Santos : 1 occurrences
#     invalid literal for int() with base 10: '14532>': 1 occurrences
#     invalid literal for int() with base 10: '-6005>': 1 occurrences
#     invalid literal for int() with base 10: '48000>': 1 occurrences
#     invalid literal for int() with base 10: '9001>': 1 occurrences
#     invalid literal for int() with base 10: '-1>': 2 occurrences
#     Invalid country: MEXICOMarried-spouse-absent: 1 occurrences
#     invalid literal for int() with base 10: '3402>': 1 occurrences
#     invalid literal for int() with base 10: '2202>': 3 occurrences
#     invalid literal for int() with base 10: '2305>': 3 occurrences
#     invalid literal for int() with base 10: '1024>': 2 occurrences
#     Invalid country: Males work but female are not specified for some countries so it has to be female or other, will use "other": 1 occurrences
#     invalid literal for int() with base 10: '2132>': 2 occurrences
#     invalid literal for int() with base 10: '-1235>': 1 occurrences
#     invalid literal for int() with base 10: '2307>': 2 occurrences
#     invalid literal for int() with base 10: '  ': 1 occurrences
#     invalid literal for int() with base 10: '1459>': 1 occurrences
#     invalid literal for int() with base 10: '3258>': 1 occurrences
#     invalid literal for int() with base 10: '1707>': 1 occurrences
#     Invalid country: MEXICOCity=Mexico: 1 occurrences
#     invalid literal for int() with base 10: '2105>': 2 occurrences
#     invalid literal for int() with base 10: '4562>': 1 occurrences
#     invalid literal for int() with base 10: '2842>': 1 occurrences
#     invalid literal for int() with base 10: '3406>': 1 occurrences
#     Invalid country: MEXICOCountry: 1 occurrences
#     invalid literal for int() with base 10: '3209>': 2 occurrences
#     Invalid country: MEXICo: 6 occurrences
#     invalid literal for int() with base 10: '3001>': 2 occurrences
#     invalid literal for int() with base 10: '4209>': 1 occurrences
#     Invalid occupation: Service-: 1 occurrences
#     invalid literal for int() with base 10: '3207>': 2 occurrences
#     invalid literal for int() with base 10: '1341>': 1 occurrences
#     invalid literal for int() with base 10: '2508>': 1 occurrences
#     invalid literal for int() with base 10: '4803>': 1 occurrences
#     invalid literal for int() with base 10: '1231>': 2 occurrences
#     invalid literal for int() with base 10: '2503>': 2 occurrences
#     invalid literal for int() with base 10: '1805>': 1 occurrences
#     Invalid country: MEXICOFemale: 1 occurrences
#     invalid literal for int() with base 10: '2137>': 2 occurrences
#     invalid literal for int() with base 10: '-3201>': 1 occurrences
#     invalid literal for int() with base 10: '1289>': 1 occurrences
#     invalid literal for int() with base 10: '2905>': 1 occurrences
#     invalid literal for int() with base 10: '1506>': 1 occurrences
#     invalid literal for int() with base 10: '2306>': 1 occurrences
#     Invalid country: MEXICAN-WIFE : 1 occurrences
#     invalid literal for int() with base 10: '2101>': 1 occurrences
#     Invalid occupation: Service-worker: 2 occurrences
#     invalid literal for int() with base 10: '4509>': 1 occurrences
#     Invalid country: Males: 2 occurrences
#     invalid literal for int() with base 10: '1111>': 1 occurrences
#     invalid literal for int() with base 10: '34567>': 2 occurrences
#     invalid literal for int() with base 10: '49.6': 1 occurrences
#     invalid literal for int() with base 10: '1209>': 1 occurrences
#     invalid literal for int() with base 10: '9000>': 2 occurrences
#     invalid literal for int() with base 10: '2103>': 1 occurrences
#     invalid literal for int() with base 10: '4568>': 1 occurrences
#     Invalid country: Males United-States: 1 occurrences
#     invalid literal for int() with base 10: '2408>': 1 occurrences
#     Invalid occupation: Service-Sales: 1 occurrences
#     invalid literal for int() with base 10: '2134>': 2 occurrences
#     invalid literal for int() with base 10: '1905>': 1 occurrences
#     invalid literal for int() with base 10: '1142>': 1 occurrences
#     invalid literal for int() with base 10: '2751>': 1 occurrences
#     invalid literal for int() with base 10: '4567>': 2 occurrences
#     invalid literal for int() with base 10: '4208>': 1 occurrences
#     invalid literal for int() with base 10: '4501>': 1 occurrences
#     invalid literal for int() with base 10: '4213>': 1 occurrences
#     invalid literal for int() with base 10: '-1214>': 1 occurrences
#     Invalid country: MEXICAN-MARITIME: 1 occurrences
#     invalid literal for int() with base 10: '1545>': 1 occurrences
#     invalid literal for int() with base 10: '2351>': 1 occurrences
#     invalid literal for int() with base 10: '8000>': 1 occurrences
#     invalid literal for int() with base 10: '-1409>': 1 occurrences
#     invalid literal for int() with base 10: '1149>': 1 occurrences
#     invalid literal for int() with base 10: '-2205>': 2 occurrences
#     invalid literal for int() with base 10: '2309>': 2 occurrences
#     invalid literal for int() with base 10: '2504>': 1 occurrences
#     invalid literal for int() with base 10: '2303>': 1 occurrences
#     invalid literal for int() with base 10: '3401>': 1 occurrences
#     invalid literal for int() with base 10: '2845>': 1 occurrences
#     invalid literal for int() with base 10: '12567>': 1 occurrences
#     invalid literal for int() with base 10: '3503>': 2 occurrences
#     invalid literal for int() with base 10: '2108>': 1 occurrences
#     invalid literal for int() with base 10: '3008>': 1 occurrences
#     invalid literal for int() with base 10: '4207>': 1 occurrences
#     invalid literal for int() with base 10: '32000>': 1 occurrences
#     invalid literal for int() with base 10: '12000>': 1 occurrences
#     invalid literal for int() with base 10: '2142>': 1 occurrences
#     Invalid occupation: Service: 2 occurrences
#     invalid literal for int() with base 10: '-2102>': 1 occurrences
#     invalid literal for int() with base 10: '4503>': 1 occurrences
#     invalid literal for int() with base 10: '1213>': 1 occurrences
#     invalid literal for int() with base 10: '2203>': 1 occurrences
#     invalid literal for int() with base 10: '6001>': 1 occurrences
#     Invalid country: MEXICOCountry : 1 occurrences
#     Invalid country: Males: Cambodia : 1 occurrences
#     invalid literal for int() with base 10: '2403>': 1 occurrences
#     invalid literal for int() with base 10: '30-39': 1 occurrences
#     invalid literal for int() with base 10: '2604>': 1 occurrences
#     Invalid country: MEXICAN-FEMME: 1 occurrences
#     invalid literal for int() with base 10: '2502>': 1 occurrences
#     invalid literal for int() with base 10: '4211>': 1 occurrences
#     invalid literal for int() with base 10: '25000>': 1 occurrences
#     invalid literal for int() with base 10: '2349>': 1 occurrences
#     Invalid country: Males were mostly in low-skilled work : 1 occurrences
#     Invalid country: MEXICOR: 1 occurrences
#     invalid literal for int() with base 10: '2109>': 3 occurrences
#     invalid literal for int() with base 10: '1223>': 1 occurrences
#     invalid literal for int() with base 10: '1452>': 1 occurrences
#     invalid literal for int() with base 10: '2343>': 1 occurrences
#     Invalid country: MEXICAN-Canada: 1 occurrences
#     invalid literal for int() with base 10: '1092>': 1 occurrences
#     Invalid country: MEXICOMarried-civ-spouse: 1 occurrences
#     invalid literal for int() with base 10: '2007>': 1 occurrences
#     invalid literal for int() with base 10: '2507>': 1 occurrences
#     invalid literal for int() with base 10: '2201>': 1 occurrences
#     invalid literal for int() with base 10: '3002>': 1 occurrences
#     invalid literal for int() with base 10: '22000>': 1 occurrences
#     Invalid country: MEXICORICESElement: 1 occurrences
#     invalid literal for int() with base 10: '2107>': 1 occurrences
#     invalid literal for int() with base 10: '2192>': 1 occurrences
#     invalid literal for int() with base 10: '3408>': 1 occurrences
#     invalid literal for int() with base 10: '30-40': 1 occurrences
#     invalid literal for int() with base 10: '4000>': 1 occurrences
#     invalid literal for int() with base 10: '14390>': 1 occurrences
#     invalid literal for int() with base 10: '3206>': 1 occurrences
#     invalid literal for int() with base 10: '18000>': 1 occurrences
#     invalid literal for int() with base 10: '-3305>': 1 occurrences
#     invalid literal for int() with base 10: '-2101>': 1 occurrences
#     invalid literal for int() with base 10: '1005>': 1 occurrences
#     invalid literal for int() with base 10: '1219>': 1 occurrences
#     invalid literal for int() with base 10: '2505>': 1 occurrences
#     invalid literal for int() with base 10: '2409>': 1 occurrences
#     invalid literal for int() with base 10: '-2208>': 1 occurrences
#     invalid literal for int() with base 10: '4005>': 1 occurrences
#     invalid literal for int() with base 10: '-1215>': 1 occurrences
#     invalid literal for int() with base 10: '24567>': 1 occurrences
#     invalid literal for int() with base 10: '-1965>': 1 occurrences
#
# Processing Model: mistral (Model 2/2)
#   Using Temperature: 5
# Generating Samples for mistral with Temp 5: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 5000/5000 [3:18:43<00:00,  2.38s/it]
#   Model mistral at Temp 5 - Error Rate: 10.22%
#   Error Distribution Summary for Model mistral at Temp 5:
#     Invalid occupation: Exectutive: 15 occurrences
#     Invalid relationship: Other: 23 occurrences
#     Invalid occupation: Exectutive-managerial: 15 occurrences
#     Invalid occupation: Execthinktank: 2 occurrences
#     invalid literal for int() with base 10: '15000<': 1 occurrences
#     Invalid marital status: Married-spouse: 21 occurrences
#     Input must have exactly 13 fields separated by |: 211 occurrences
#     Invalid occupation: Exectec-managerial: 30 occurrences
#     Invalid occupation: Exect-managerial: 40 occurrences
#     Invalid occupation: Executive: 16 occurrences
#     Invalid occupation: Executive-managerial: 26 occurrences
#     Invalid occupation: Execthys-managerial: 1 occurrences
#     Invalid occupation: Exectemp-managerial: 13 occurrences
#     Invalid education: Professional-school: 1 occurrences
#     Invalid occupation: Exectechnicalmanagerial: 7 occurrences
#     Invalid occupation: Exectech-managerial: 15 occurrences
#     Invalid occupation: Exectech-support: 4 occurrences
#     Invalid occupation: Execthospitalitymanager: 1 occurrences
#     Invalid occupation: Exectechnicalanalyst: 2 occurrences
#     Invalid occupation: Exectechnicalsupportmanager: 2 occurrences
#     Invalid education: Prof-specialty: 2 occurrences
#     Invalid occupation: Execthe-managerial: 2 occurrences
#     Invalid occupation: Exectempmanagerial: 9 occurrences
#     Invalid occupation: Exectechnical: 10 occurrences
#     Invalid occupation: Execthys: 1 occurrences
#     Invalid occupation: Execthe support: 1 occurrences
#     Invalid occupation: Execthechicality: 1 occurrences
#     Invalid occupation: Exectechnicalspecialist: 4 occurrences
#     Invalid occupation: Exectechnicalworker: 3 occurrences
#     Invalid education: High-school: 1 occurrences
#     Invalid occupation: Execth-managerial: 1 occurrences
#     Invalid occupation: Execthe support,: 1 occurrences
#     Invalid occupation: Exectheoretical physicist: 1 occurrences
#     Invalid education: Professor-school: 1 occurrences
#     Invalid occupation: Exectechnicalsupportanalyst: 1 occurrences
#     invalid literal for int() with base 10: '3000<': 1 occurrences
#     Invalid occupation: Exectechnicalspecialty: 3 occurrences
#     Invalid occupation: Exectechnicalsupportmanagerial: 2 occurrences
#     Capital loss must be between 0 and 99999: 1 occurrences
#     invalid literal for int() with base 10: '20000<': 1 occurrences
#     Invalid occupation: Execthical: 1 occurrences
#     Invalid occupation: Exectemp: 1 occurrences
#     Invalid occupation: Execthic: 1 occurrences
#     invalid literal for int() with base 10: '40000<': 1 occurrences
#     Invalid occupation: Exectechnicalmanager: 2 occurrences
#     Invalid occupation: Executive-management: 3 occurrences
#     invalid literal for int() with base 10: '5000<': 1 occurrences
#     Invalid occupation: Exectheoreticalcomputing: 1 occurrences
#     Invalid occupation: Exectechnicalsupport: 3 occurrences
#     invalid literal for int() with base 10: '25000<': 1 occurrences
#     Invalid occupation: Exectheoretical-physisicist: 1 occurrences
#     Invalid occupation: Execthings: 1 occurrences
#     Invalid occupation: Execthe_managerial: 1 occurrences
#
#   Using Temperature: 10
# Generating Samples for mistral with Temp 10: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 5000/5000 [11:48:57<00:00,  8.51s/it]
#   Model mistral at Temp 10 - Error Rate: 10.88%
#   Error Distribution Summary for Model mistral at Temp 10:
#     Input must have exactly 13 fields separated by |: 194 occurrences
#     Invalid occupation: Exectemp-managerial: 18 occurrences
#     Invalid occupation: Exectutive-managerial: 15 occurrences
#     Invalid occupation: Executive: 24 occurrences
#     Invalid occupation: Executive-managerial: 30 occurrences
#     Invalid relationship: Other: 37 occurrences
#     Invalid occupation: Execthespetiality: 1 occurrences
#     Invalid marital status: Married-spouse: 21 occurrences
#     Invalid occupation: Exectutive: 21 occurrences
#     Invalid occupation: Execthic-managerial: 1 occurrences
#     Invalid occupation: Execthicalspecialty: 1 occurrences
#     Capital loss must be between 0 and 99999: 2 occurrences
#     Invalid occupation: Exect-managerial: 40 occurrences
#     Invalid occupation: Exectechnicalsupportmanager: 3 occurrences
#     Invalid occupation: Exectechnical: 11 occurrences
#     Invalid occupation: Execthechsupport: 1 occurrences
#     Invalid occupation: Exectec-managerial: 18 occurrences
#     Invalid occupation: Exectechnicalsupportmanagerial: 2 occurrences
#     Invalid occupation: Execthinktank: 1 occurrences
#     Invalid occupation: Exectech-managerial: 25 occurrences
#     Invalid occupation: Executive-management: 9 occurrences
#     invalid literal for int() with base 10: '5000<': 1 occurrences
#     Invalid occupation: Exectechnicalspecialty: 3 occurrences
#     Invalid relationship: Unemployed: 1 occurrences
#     Invalid education: Prof-specialty: 4 occurrences
#     Invalid occupation: Execthemanagerial: 2 occurrences
#     Invalid occupation: Execthysician: 1 occurrences
#     Invalid occupation: Exectechnicalmanager: 4 occurrences
#     Invalid occupation: Exectechnicalsupportworker: 1 occurrences
#     Invalid occupation: Execthings: 1 occurrences
#     Invalid occupation: Exectechnicalmanagerial: 4 occurrences
#     Invalid occupation: Execthreader: 1 occurrences
#     Invalid occupation: Exectempmanagerial: 11 occurrences
#     Invalid occupation: Exectheatreproducer: 1 occurrences
#     Invalid occupation: Exectechnicalworker: 1 occurrences
#     Invalid occupation: Execthys: 1 occurrences
#     Invalid occupation: Execthosecretary: 1 occurrences
#     Invalid occupation: Exectechnicalsupportanalyst: 3 occurrences
#     Invalid occupation: Exectech-support: 6 occurrences
#     Invalid occupation: Exectechnicalsupport: 2 occurrences
#     Invalid occupation: Execthanker: 1 occurrences
#     invalid literal for int() with base 10: '30000<': 1 occurrences
#     Invalid occupation: Execthe_managerial: 1 occurrences
#     invalid literal for int() with base 10: '3000<': 1 occurrences
#     Invalid occupation: Exectheatsupport: 1 occurrences
#     Invalid occupation: Execthreadhead: 1 occurrences
#     Invalid occupation: Execthroughspecialty: 1 occurrences
#     Invalid occupation: Execthroughfinancialmanager: 1 occurrences
#     Invalid occupation: Execthead: 1 occurrences
#     Invalid occupation: Execthreadlighter: 1 occurrences
#     Invalid occupation: Execthreadsafeexecutivesystemarchitect: 1 occurrences
#     Invalid occupation: Exectheatremanagement: 1 occurrences
#     Invalid occupation: Exectechnicalanalyst: 1 occurrences
#     Invalid occupation: Exectechnicalspecialist: 1 occurrences
#     Invalid occupation: Execthankgod: 1 occurrences
#     Invalid occupation: Execthemeanspecialty: 1 occurrences
#     Invalid occupation: Execthysseciaral: 1 occurrences
#     Invalid occupation: Exectheat-managerial: 1 occurrences
#     Invalid occupation: Execthical: 1 occurrences
#     Invalid occupation: Exectheoremangerial: 1 occurrences
#
#   Using Temperature: 15
# Generating Samples for mistral with Temp 15: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 5000/5000 [5:44:32<00:00,  4.13s/it]
#   Model mistral at Temp 15 - Error Rate: 12.00%
#   Error Distribution Summary for Model mistral at Temp 15:
#     Invalid relationship: Other: 52 occurrences
#     Input must have exactly 13 fields separated by |: 225 occurrences
#     invalid literal for int() with base 10: '15000<': 1 occurrences
#     Invalid occupation: Exectec-managerial: 40 occurrences
#     Invalid occupation: Executive: 26 occurrences
#     Invalid occupation: Exectech-managerial: 24 occurrences
#     Invalid occupation: Execthehelp-managerial: 1 occurrences
#     Invalid occupation: Exectutive-managerial: 17 occurrences
#     Invalid occupation: Exect-managerial: 37 occurrences
#     Invalid occupation: Executive-managerial: 18 occurrences
#     Invalid occupation: Exectechnicalsupport: 3 occurrences
#     Invalid occupation: Exectemp-managerial: 13 occurrences
#     invalid literal for int() with base 10: '30000<': 1 occurrences
#     Invalid education: Prof-specialty: 16 occurrences
#     Invalid occupation: Exectech-support: 6 occurrences
#     Invalid marital status: Married-spouse: 11 occurrences
#     Invalid occupation: Exectechnicalmanagerial: 6 occurrences
#     Invalid occupation: Exectutive: 24 occurrences
#     Invalid occupation: Executive-management: 11 occurrences
#     Invalid occupation: Exectechnicalworker: 3 occurrences
#     Invalid occupation: Execth-managerial: 4 occurrences
#     invalid literal for int() with base 10: '45000<': 1 occurrences
#     Invalid occupation: Exectechnical: 5 occurrences
#     Invalid occupation: Exectempmanagerial: 12 occurrences
#     Invalid education: High-school: 2 occurrences
#     Invalid occupation: Exectheh: 1 occurrences
#     Invalid occupation: Exectechnicalspecialist: 1 occurrences
#     Invalid occupation: Execthose-managerial: 1 occurrences
#     Invalid occupation: Execthe support, Prof-specialty, Priv-house-serv: 1 occurrences
#     Invalid occupation: Execthe managerial: 1 occurrences
#     Invalid occupation: Execthemeanspecialty: 1 occurrences
#     invalid literal for int() with base 10: '3000<': 1 occurrences
#     Invalid relationship: Unemployed: 2 occurrences
#     Invalid occupation: Execthreatmental: 1 occurrences
#     Invalid occupation: Execthreaded specialty: 1 occurrences
#     Invalid occupation: Execthings: 2 occurrences
#     Invalid occupation: Exectheatssupport: 1 occurrences
#     Invalid occupation: Execthreadless: 1 occurrences
#     Invalid occupation: Execthreshold management, Sales: 1 occurrences
#     Invalid occupation: Exectechnicalsupportmanagerial: 1 occurrences
#     Invalid occupation: Execthe_managerial: 1 occurrences
#     invalid literal for int() with base 10: '25000<': 2 occurrences
#     Invalid occupation: Execthech support, craft-repair, other-service: 1 occurrences
#     invalid literal for int() with base 10: '20000<': 2 occurrences
#     Invalid occupation: Execthechspecialty: 1 occurrences
#     Invalid occupation: Exectechnicalspecialty: 3 occurrences
#     Invalid occupation: Execthysmanagerial: 1 occurrences
#     Invalid education: Highschool: 1 occurrences
#     Invalid occupation: Execthehelpdesk: 1 occurrences
#     Capital loss must be between 0 and 99999: 4 occurrences
#     Invalid occupation: Execthospitality: 1 occurrences
#     Invalid occupation: Execthirdparty, Other-service, Handlers-cleaners, Sales: 1 occurrences
#     Invalid education: Professor-School: 1 occurrences
#     Invalid occupation: Execthys-managerial: 1 occurrences
#     Invalid education: Professional-school: 1 occurrences
#     invalid literal for int() with base 10: '10000<': 1 occurrences
#     Invalid occupation: Execthreada-managerial: 1 occurrences

# %% [markdown]
# # Process and Evaluate results

# %%
def preprocess(df):
    # Correct column names
    df.columns = df.columns.str.lower().str.replace('-', '_')

    # Clean the income column by stripping spaces and removing periods
    df['target'] = df['target'].str.replace('.', '', regex=False).str.strip()
    
    # Encode '>50K' as 1 and '<=50K' as 0
    df['target'] = df['target'].map({'>50K': 1, '<50K': 0})

    # The dataset has native class for missing data: "?"
    df = df.fillna('?')

    # One-Hot Encoding for categorical variables
    df = pd.get_dummies(df, columns=['relationship', 'marital_status', 'race', 'sex'], drop_first=True)
    df.columns = df.columns.str.lower().str.replace('-', '_') # lower case and use _ instead of -
    
    # Integer Encoding for workclass, occupation, and native-country
    encoder = LabelEncoder()

    # col name missmatches
    df.rename(columns={'country': 'native_country', 'education': 'education_num', 'hours_weekly': 'hours_per_week'}, inplace=True)
    
    # Apply integer encoding
    df['workclass'] = encoder.fit_transform(df['workclass'])
    df['occupation'] = encoder.fit_transform(df['occupation'])
    df['native_country'] = encoder.fit_transform(df['native_country'])
    df['education_num'] = encoder.fit_transform(df['education_num'])
        
    # Convert boolean columns to integers
    df = df.astype(int)

    # HOT ENCODING ISSUE IF YOU MISS CERTAIN VALUES THE COLUMN WONT BE GENERATED
    # Get the columns in X_train_base that are missing in df
    missing_cols = set(X_train_base.columns) - set(df.columns)
    
    # Add the missing columns to df with 0 as the default value
    for col in missing_cols:
        df[col] = 0
    
    # REORDER COLUMNS
    ordered_columns = [col for col in X_train_base.columns if col != 'target']  
    
    # Add 'target' at the end
    ordered_columns += ['target']  
    
    # Reorder
    df = df[ordered_columns]
    
    # List of columns to scale (all columns except 'income')
    numeric_cols = df.columns[df.columns != 'target']
  
    # Initialize the scaler
    scaler = StandardScaler()
    
    # Scale the numerical features and update the DataFrame
    df[numeric_cols] = scaler.fit_transform(df[numeric_cols])

    return df

# %%
# Define the column structure
columns = [
    "Age", "Sex", "Country", "Marital-Status", "Occupation", "Workclass",  "Education",
    "Race", "Relationship", "Hours-Weekly", "Capital-Gain", "Capital-Loss", "Target"
]

for model in models:
    for temp in temperatures:
        # Get the list of pipe-separated strings
        rows = results[model][temp]
        
        # Split each string into a list of values
        split_rows = [row.split('|') for row in rows]
        
        # Create DataFrame
        df = pd.DataFrame(split_rows, columns=columns)
        df = preprocess(df)

        # Split the data into X and y
        X_train = df.drop('target', axis=1)
        y_train = df['target']
        
        # Print the shapes of the sets
        print("Model: " + model + ", Temperature = " + str(temp))
        print(f"Training Set: X_train shape = {X_train.shape}, y_train shape = {y_train.shape}")
        print(f"Test Set: X_test shape = {X_test_base.shape}, y_test shape = {y_test_base.shape}") # We use the test data from base!
        print()
        
        temp_result = []
        for name, ml_model in ml_models:
            # Train the model
            ml_model.fit(X_train, y_train)
        
            # Predict on test set
            y_test_pred_base = ml_model.predict(X_test_base)

            # Store results for the model
            model_results = {
                'Model': name,
                'Test Accuracy': accuracy_score(y_test_base, y_test_pred_base),
                'Test Precision': precision_score(y_test_base, y_test_pred_base),
                'Test Recall': recall_score(y_test_base, y_test_pred_base),
                'Test F1-Score': f1_score(y_test_base, y_test_pred_base)
            }
        
            temp_result.append(model_results)

        # Convert results to a pandas DataFrame
        results_df = pd.DataFrame(temp_result).set_index("Model")

        # Calculate difference dfs (absolute and % difference)
        result_diff = results_df - base_results
        result_pct_diff = (result_diff / base_results) * 100

        print("Results Data Synthesis:")
        display(results_df)
        print("Absolute Difference with base:")
        display(result_diff)
        print("Percentage Difference with base (%):")
        display(result_pct_diff)
        print()
        euclidean(df)
        pca(df)
        print()
# Out:
# Model: llama3.1, Temperature = 5
# Training Set: X_train shape = (3675, 24), y_train shape = (3675,)
# Test Set: X_test shape = (9769, 24), y_test shape = (9769,)
#
# Results Data Synthesis:
#                      Test Accuracy  Test Precision  Test Recall  Test F1-Score
# Model
# Logistic Regression       0.293582        0.237347     0.872187       0.373149
# Random Forest             0.391545        0.241836     0.713800       0.361272
# SVM                       0.268605        0.241918     0.953291       0.385905
# KNN                       0.416931        0.225472     0.582590       0.325118
# Gradient Boosting         0.264920        0.237660     0.928238       0.378430
# Absolute Difference with base:
#                      Test Accuracy  Test Precision  Test Recall  Test F1-Score
# Model
# Logistic Regression      -0.516941       -0.399610     0.374522      -0.185611
# Random Forest            -0.422049       -0.413578     0.235669      -0.191637
# SVM                      -0.534446       -0.403592     0.547346      -0.112531
# KNN                      -0.375064       -0.366866     0.142675      -0.179755
# Gradient Boosting        -0.539973       -0.365844     0.372399      -0.200262
# Percentage Difference with base (%):
#                      Test Accuracy  Test Precision  Test Recall  Test F1-Score
# Model
# Logistic Regression     -63.778732      -62.737348    75.255973     -33.218384
# Random Forest           -51.874685      -63.101799    49.289520     -34.659766
# SVM                     -66.551944      -62.522938   134.832636     -22.576881
# KNN                     -47.356857      -61.935197    32.432432     -35.603945
# Gradient Boosting       -67.086354      -60.619914    66.997708     -34.605935
# Average pairwise distance: 5.395649650763941
# Explained variance ratio: [0.22420605 0.09137142 0.07945485]
# Cumulative explained variance: 0.39503231599062827
#
# Model: llama3.1, Temperature = 10
# Training Set: X_train shape = (3636, 24), y_train shape = (3636,)
# Test Set: X_test shape = (9769, 24), y_test shape = (9769,)
#
# Results Data Synthesis:
#                      Test Accuracy  Test Precision  Test Recall  Test F1-Score
# Model
# Logistic Regression       0.385198        0.242851     0.732059       0.364713
# Random Forest             0.471389        0.247256     0.583439       0.347321
# SVM                       0.459617        0.271776     0.739278       0.397443
# KNN                       0.478248        0.247048     0.568577       0.344437
# Gradient Boosting         0.406695        0.242015     0.685350       0.357713
# Absolute Difference with base:
#                      Test Accuracy  Test Precision  Test Recall  Test F1-Score
# Model
# Logistic Regression      -0.425325       -0.394105     0.234395      -0.194047
# Random Forest            -0.342205       -0.408158     0.105308      -0.205589
# SVM                      -0.343433       -0.373733     0.333333      -0.100993
# KNN                      -0.313748       -0.345291     0.128662      -0.160436
# Gradient Boosting        -0.398198       -0.361489     0.129512      -0.220979
# Percentage Difference with base (%):
#                      Test Accuracy  Test Precision  Test Recall  Test F1-Score
# Model
# Logistic Regression     -52.475373      -61.873205    47.098976     -34.728136
# Random Forest           -42.060896      -62.274839    22.024867     -37.183104
# SVM                     -42.766093      -57.897392    82.112971     -20.261916
# KNN                     -39.614838      -58.292770    29.247104     -31.777477
# Gradient Boosting       -49.472212      -59.898306    23.300229     -38.185922
# Average pairwise distance: 5.403706230133437
# Explained variance ratio: [0.23574284 0.08675399 0.07921573]
# Cumulative explained variance: 0.401712562871683
#
# Model: llama3.1, Temperature = 15
# Training Set: X_train shape = (3538, 24), y_train shape = (3538,)
# Test Set: X_test shape = (9769, 24), y_test shape = (9769,)
#
# Results Data Synthesis:
#                      Test Accuracy  Test Precision  Test Recall  Test F1-Score
# Model
# Logistic Regression       0.492374        0.305672     0.869639       0.452347
# Random Forest             0.476610        0.275553     0.718896       0.398400
# SVM                       0.339851        0.254144     0.898514       0.396218
# KNN                       0.457058        0.252310     0.637792       0.361579
# Gradient Boosting         0.324701        0.238729     0.822930       0.370095
# Absolute Difference with base:
#                      Test Accuracy  Test Precision  Test Recall  Test F1-Score
# Model
# Logistic Regression      -0.318149       -0.331285     0.371975      -0.106414
# Random Forest            -0.336984       -0.379860     0.240764      -0.154510
# SVM                      -0.463200       -0.391366     0.492569      -0.102218
# KNN                      -0.334937       -0.340029     0.197877      -0.143294
# Gradient Boosting        -0.480192       -0.364775     0.267091      -0.208597
# Percentage Difference with base (%):
#                      Test Accuracy  Test Precision  Test Recall  Test F1-Score
# Model
# Logistic Regression     -39.252336      -52.010595    74.744027     -19.044595
# Random Forest           -41.419225      -57.957308    50.355240     -27.944830
# SVM                     -57.680051      -60.629002   121.338912     -20.507811
# KNN                     -42.290293      -57.404462    44.980695     -28.382189
# Gradient Boosting       -59.659163      -60.442883    48.051948     -36.046308
# Average pairwise distance: 5.428985269476137
# Explained variance ratio: [0.23204106 0.08782905 0.07876423]
# Cumulative explained variance: 0.3986343308650695
#
# Model: mistral, Temperature = 5
# Training Set: X_train shape = (4489, 24), y_train shape = (4489,)
# Test Set: X_test shape = (9769, 24), y_test shape = (9769,)
# C:\Users\danie\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Results Data Synthesis:
#                      Test Accuracy  Test Precision  Test Recall  Test F1-Score
# Model
# Logistic Regression       0.751459        0.152381     0.006794       0.013008
# Random Forest             0.713891        0.127119     0.031847       0.050934
# SVM                       0.758931        0.000000     0.000000       0.000000
# KNN                       0.654622        0.202569     0.147346       0.170600
# Gradient Boosting         0.754632        0.243902     0.008493       0.016414
# Absolute Difference with base:
#                      Test Accuracy  Test Precision  Test Recall  Test F1-Score
# Model
# Logistic Regression      -0.059064       -0.484576    -0.490870      -0.545752
# Random Forest            -0.099703       -0.528295    -0.446285      -0.501976
# SVM                      -0.044119       -0.645510    -0.405945      -0.498436
# KNN                      -0.137373       -0.389770    -0.292569      -0.334273
# Gradient Boosting        -0.050261       -0.359601    -0.547346      -0.562278
# Percentage Difference with base (%):
#                      Test Accuracy  Test Precision  Test Recall  Test F1-Score
# Model
# Logistic Regression      -7.287194      -76.076711   -98.634812     -97.671966
# Random Forest           -12.254655      -80.604811   -93.339254     -90.788041
# SVM                      -5.493945     -100.000000  -100.000000    -100.000000
# KNN                     -17.345224      -65.801885   -66.505792     -66.209383
# Gradient Boosting        -6.244436      -59.585608   -98.472116     -97.163666
# Average pairwise distance: 5.940508158478192
# Explained variance ratio: [0.14749869 0.07429649 0.0638824 ]
# Cumulative explained variance: 0.2856775775177582
#
# Model: mistral, Temperature = 10
# Training Set: X_train shape = (4456, 24), y_train shape = (4456,)
# Test Set: X_test shape = (9769, 24), y_test shape = (9769,)
# C:\Users\danie\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Results Data Synthesis:
#                      Test Accuracy  Test Precision  Test Recall  Test F1-Score
# Model
# Logistic Regression       0.753199        0.166667     0.005945       0.011480
# Random Forest             0.751152        0.058140     0.002123       0.004097
# SVM                       0.758931        0.000000     0.000000       0.000000
# KNN                       0.687583        0.179393     0.082803       0.113306
# Gradient Boosting         0.758727        0.000000     0.000000       0.000000
# Absolute Difference with base:
#                      Test Accuracy  Test Precision  Test Recall  Test F1-Score
# Model
# Logistic Regression      -0.057324       -0.470290    -0.491720      -0.547280
# Random Forest            -0.062442       -0.597274    -0.476008      -0.548813
# SVM                      -0.044119       -0.645510    -0.405945      -0.498436
# KNN                      -0.104412       -0.412946    -0.357113      -0.391567
# Gradient Boosting        -0.046166       -0.603504    -0.555839      -0.578691
# Percentage Difference with base (%):
#                      Test Accuracy  Test Precision  Test Recall  Test F1-Score
# Model
# Logistic Regression      -7.072493      -73.833902   -98.805461     -97.945432
# Random Forest            -7.674887      -91.129332   -99.555950     -99.259068
# SVM                      -5.493945     -100.000000  -100.000000    -100.000000
# KNN                     -13.183404      -69.714474   -81.177606     -77.557494
# Gradient Boosting        -5.735724     -100.000000  -100.000000    -100.000000
# Average pairwise distance: 6.042585665656159
# Explained variance ratio: [0.14922874 0.07005927 0.06487497]
# Cumulative explained variance: 0.2841629725394981
#
# Model: mistral, Temperature = 15
# Training Set: X_train shape = (4400, 24), y_train shape = (4400,)
# Test Set: X_test shape = (9769, 24), y_test shape = (9769,)
# C:\Users\danie\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Results Data Synthesis:
#                      Test Accuracy  Test Precision  Test Recall  Test F1-Score
# Model
# Logistic Regression       0.751868        0.210084     0.010616       0.020210
# Random Forest             0.748797        0.143885     0.008493       0.016038
# SVM                       0.758931        0.000000     0.000000       0.000000
# KNN                       0.717781        0.275670     0.104883       0.151953
# Gradient Boosting         0.751356        0.130000     0.005520       0.010591
# Absolute Difference with base:
#                      Test Accuracy  Test Precision  Test Recall  Test F1-Score
# Model
# Logistic Regression      -0.058655       -0.426872    -0.487049      -0.538550
# Random Forest            -0.064797       -0.511528    -0.469639      -0.536871
# SVM                      -0.044119       -0.645510    -0.405945      -0.498436
# KNN                      -0.074214       -0.316669    -0.335032      -0.352920
# Gradient Boosting        -0.053537       -0.473504    -0.550318      -0.568101
# Percentage Difference with base (%):
#                      Test Accuracy  Test Precision  Test Recall  Test F1-Score
# Model
# Logistic Regression      -7.236676      -67.017524   -97.866894     -96.383032
# Random Forest            -7.964268      -78.046692   -98.223801     -97.099255
# SVM                      -5.493945     -100.000000  -100.000000    -100.000000
# KNN                      -9.370557      -53.460791   -76.158301     -69.902697
# Gradient Boosting        -6.651405      -78.459129   -99.006875     -98.169900
# Average pairwise distance: 6.076252105833049
# Explained variance ratio: [0.15446225 0.07023303 0.06447521]
# Cumulative explained variance: 0.28917048568284953

# %%
# Get unique classes and counts
unique_classes, counts = np.unique(y_test, return_counts=True)
class_balance = dict(zip(unique_classes, counts))

print("Class Balance (Counts):", class_balance)
print("Class Balance (%):", {cls: count / len(y_test) * 100 for cls, count in class_balance.items()})
# Out:
# Class Balance (Counts): {0: 7414, 1: 2355}
# Class Balance (%): {0: 75.89313133381104, 1: 24.106868666188966}
